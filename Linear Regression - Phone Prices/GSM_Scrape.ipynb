# %% [markdown]
# ### This is the code I found that scrapes the GSMArena website for the data that I used for my regression project. Not my code. My data came from the subsequent Kaggle dataset that used this scraping code

# %%
import requests
from bs4 import BeautifulSoup
import csv
import os
import time

# Class gsmarena scrap the website phones models and its devices and save to csv file individually.
class Gsmarena():

    # Constructor to initialize common useful varibales throughout the program.
    def __init__(self):
        self.phones = []
        self.features = ["Brand", "Model Name", "Model Image"]
        self.temp1 = []
        self.phones_brands = []
        self.url = 'https://www.gsmarena.com/' # GSMArena website url
        self.new_folder_name = 'GSMArenaDataset' # Folder name on which files going to save.
        self.absolute_path = os.popen('pwd').read().strip() + '/' + self.new_folder_name  # It create the absolute path of the GSMArenaDataset folder.

    # This function crawl the html code of the requested URL.
    def crawl_html_page(self, sub_url):

        url = self.url + sub_url  # Url for html content parsing.

        # Handing the connection error of the url.
        try:
            page = requests.get(url)
            soup = BeautifulSoup(page.text, 'html.parser')  # It parses the html data from requested url.
            return soup

        except ConnectionError as err:
            print("Please check your network connection and re-run the script.")
            exit()

        except Exception:
            print("Please check your network connection and re-run the script.")
            exit()

    # This function crawl mobile phones brands and return the list of the brands.
    def crawl_phone_brands(self):
        phones_brands = []
        soup = self.crawl_html_page('makers.php3')
        table = soup.find_all('table')[0]
        table_a = table.find_all('a')
        for a in table_a:
            temp = [a['href'].split('-')[0], a.find('span').text.split(' ')[0], a['href']]
            phones_brands.append(temp)
        return phones_brands

    # This function crawl mobile phones brands models links and return the list of the links.
    def crawl_phones_models(self, phone_brand_link):
        links = []
        nav_link = []
        soup = self.crawl_html_page(phone_brand_link)
        nav_data = soup.find(class_='nav-pages')
        if not nav_data:
            nav_link.append(phone_brand_link)
        else:
            nav_link = nav_data.findAll('a')
            nav_link = [link['href'] for link in nav_link]
            nav_link.append(phone_brand_link)
            nav_link.insert(0, nav_link.pop())
        for link in nav_link:
            soup = self.crawl_html_page(link)
            data = soup.find(class_='section-body')
            for line1 in data.findAll('a'):
                links.append(line1['href'])

        return links

    # This function crawl mobile phones specification and return the list of the all devices list of single brand.
    def crawl_phones_models_specification(self, link, phone_brand):
        phone_data = {}
        soup = self.crawl_html_page(link)
        model_name = soup.find(class_='specs-phone-name-title').text
        model_img_html = soup.find(class_='specs-photo-main')
        model_img = model_img_html.find('img')['src']
        phone_data.update({"Brand": phone_brand})
        phone_data.update({"Model Name": model_name})
        phone_data.update({"Model Image": model_img})
        temp = []
        for data1 in range(len(soup.findAll('table'))):
            table = soup.findAll('table')[data1]
            for line in table.findAll('tr'):
                temp = []
                for l in line.findAll('td'):
                    text = l.getText()
                    text = text.strip()
                    text = text.lstrip()
                    text = text.rstrip()
                    text = text.replace("\n", "")
                    temp.append(text)
                    if temp[0] in phone_data.keys():
                        temp[0] = temp[0] + '_1'
                    if temp[0] not in self.features:
                        self.features.append(temp[0])
                if not temp:
                    continue
                else:
                    phone_data.update({temp[0]: temp[1]})
        return phone_data

    # This function create the folder 'GSMArenaDataset'.
    def create_folder(self):
        if not os.path.exists(self.new_folder_name):
            os.system('mkdir ' + self.new_folder_name)
            print("Creating ", self.new_folder_name, " Folder....")
            time.sleep(6)
            print("Folder Created.")
        else:
            print(self.new_folder_name , "directory already exists")

    # This function check the csv file exists in the 'GSMArenaDataset' directory or not.
    def check_file_exists(self):
        return os.listdir(self.absolute_path)

    # This function save the devices specification to csv file.
    def save_specification_to_file(self):
        phone_brand = self.crawl_phone_brands()
        self.create_folder()
        files_list = self.check_file_exists()
        for brand in phone_brand:
            phones_data = []
            if (brand[0].title() + '.csv') not in files_list:
                link = self.crawl_phones_models(brand[2])
                model_value = 1
                print("Working on", brand[0].title(), "brand.")
                for value in link:
                    datum = self.crawl_phones_models_specification(value, brand[0])
                    datum = { k:v.replace('\n', ' ').replace('\r', ' ') for k,v in datum.items() }
                    phones_data.append(datum)
                    print("Completed ", model_value, "/", len(link))
                    model_value+=1
                with open(self.absolute_path + '/' + brand[0].title() + ".csv", "w")  as file:
                    dict_writer = csv.DictWriter(file, fieldnames=self.features)
                    dict_writer.writeheader()
                    dict_writer.writerows(phones_data)
                print("Data loaded in the file")
            else:
                print(brand[0].title() + '.csv file already in your directory.')


# This is the main function which create the object of Gsmarena class and call the save_specificiton_to_file function.
i = 1
while i == 1:
    if __name__ == "__main__":
        obj = Gsmarena()
        try:
            obj.save_specification_to_file()
        except KeyboardInterrupt:
            print("File has been stopped due to KeyBoard Interruption.")
# Out:
# Creating  GSMArenaDataset  Folder....
# Folder Created.
# Working on Acer brand.
# Completed  1 / 100
# Completed  2 / 100
# Completed  3 / 100
# Completed  4 / 100
# Completed  5 / 100
# Completed  6 / 100
# Completed  7 / 100
# Completed  8 / 100
# Completed  9 / 100
# Completed  10 / 100
# Completed  11 / 100
# Completed  12 / 100
# Completed  13 / 100
# Completed  14 / 100
# Completed  15 / 100
# Completed  16 / 100
# Completed  17 / 100
# Completed  18 / 100
# Completed  19 / 100
# Completed  20 / 100
# Completed  21 / 100
# Completed  22 / 100
# Completed  23 / 100
# Completed  24 / 100
# Completed  25 / 100
# Completed  26 / 100
# Completed  27 / 100
# Completed  28 / 100
# Completed  29 / 100
# Completed  30 / 100
# Completed  31 / 100
# Completed  32 / 100
# Completed  33 / 100
# Completed  34 / 100
# Completed  35 / 100
# Completed  36 / 100
# Completed  37 / 100
# Completed  38 / 100
# Completed  39 / 100
# Completed  40 / 100
# Completed  41 / 100
# Completed  42 / 100
# Completed  43 / 100
# Completed  44 / 100
# Completed  45 / 100
# Completed  46 / 100
# Completed  47 / 100
# Completed  48 / 100
# Completed  49 / 100
# Completed  50 / 100
# Completed  51 / 100
# Completed  52 / 100
# Completed  53 / 100
# Completed  54 / 100
# Completed  55 / 100
# Completed  56 / 100
# Completed  57 / 100
# Completed  58 / 100
# Completed  59 / 100
# Completed  60 / 100
# Completed  61 / 100
# Completed  62 / 100
# Completed  63 / 100
# Completed  64 / 100
# Completed  65 / 100
# Completed  66 / 100
# Completed  67 / 100
# Completed  68 / 100
# Completed  69 / 100
# Completed  70 / 100
# Completed  71 / 100
# Completed  72 / 100
# Completed  73 / 100
# Completed  74 / 100
# Completed  75 / 100
# Completed  76 / 100
# Completed  77 / 100
# Completed  78 / 100
# Completed  79 / 100
# Completed  80 / 100
# Completed  81 / 100
# Completed  82 / 100
# Completed  83 / 100
# Completed  84 / 100
# Completed  85 / 100
# Completed  86 / 100
# Completed  87 / 100
# Completed  88 / 100
# Completed  89 / 100
# Completed  90 / 100
# Completed  91 / 100
# Completed  92 / 100
# Completed  93 / 100
# Completed  94 / 100
# Completed  95 / 100
# Completed  96 / 100
# Completed  97 / 100
# Completed  98 / 100
# Completed  99 / 100
# Completed  100 / 100
# Data loaded in the file
# Working on Alcatel brand.
# Completed  1 / 385
# Completed  2 / 385
# Completed  3 / 385
# Completed  4 / 385
# Completed  5 / 385
# Completed  6 / 385
# Completed  7 / 385
# Completed  8 / 385
# Completed  9 / 385
# Completed  10 / 385
# Completed  11 / 385
# Completed  12 / 385
# Completed  13 / 385
# Completed  14 / 385
# Completed  15 / 385
# Completed  16 / 385
# Completed  17 / 385
# Completed  18 / 385
# Completed  19 / 385
# Completed  20 / 385
# Completed  21 / 385
# Completed  22 / 385
# Completed  23 / 385
# Completed  24 / 385
# Completed  25 / 385
# Completed  26 / 385
# Completed  27 / 385
# Completed  28 / 385
# Completed  29 / 385
# Completed  30 / 385
# Completed  31 / 385
# Completed  32 / 385
# Completed  33 / 385
# Completed  34 / 385
# Completed  35 / 385
# Completed  36 / 385
# Completed  37 / 385
# Completed  38 / 385
# Completed  39 / 385
# Completed  40 / 385
# Completed  41 / 385
# Completed  42 / 385
# Completed  43 / 385
# Completed  44 / 385
# Completed  45 / 385
# Completed  46 / 385
# Completed  47 / 385
# Completed  48 / 385
# Completed  49 / 385
# Completed  50 / 385
# Completed  51 / 385
# Completed  52 / 385
# Completed  53 / 385
# Completed  54 / 385
# Completed  55 / 385
# Completed  56 / 385
# Completed  57 / 385
# Completed  58 / 385
# Completed  59 / 385
# Completed  60 / 385
# Completed  61 / 385
# Completed  62 / 385
# Completed  63 / 385
# Completed  64 / 385
# Completed  65 / 385
# Completed  66 / 385
# Completed  67 / 385
# Completed  68 / 385
# Completed  69 / 385
# Completed  70 / 385
# Completed  71 / 385
# Completed  72 / 385
# Completed  73 / 385
# Completed  74 / 385
# Completed  75 / 385
# Completed  76 / 385
# Completed  77 / 385
# Completed  78 / 385
# Completed  79 / 385
# Completed  80 / 385
# Completed  81 / 385
# Completed  82 / 385
# Completed  83 / 385
# Completed  84 / 385
# Completed  85 / 385
# Completed  86 / 385
# Completed  87 / 385
# Completed  88 / 385
# Completed  89 / 385
# Completed  90 / 385
# Completed  91 / 385
# Completed  92 / 385
# Completed  93 / 385
# Completed  94 / 385
# Completed  95 / 385
# Completed  96 / 385
# Completed  97 / 385
# Completed  98 / 385
# Completed  99 / 385
# Completed  100 / 385
# Completed  101 / 385
# Completed  102 / 385
# Completed  103 / 385
# Completed  104 / 385
# Completed  105 / 385
# Completed  106 / 385
# Completed  107 / 385
# Completed  108 / 385
# Completed  109 / 385
# Completed  110 / 385
# Completed  111 / 385
# Completed  112 / 385
# Completed  113 / 385
# Completed  114 / 385
# Completed  115 / 385
# Completed  116 / 385
# Completed  117 / 385
# Completed  118 / 385
# Completed  119 / 385
# Completed  120 / 385
# Completed  121 / 385
# Completed  122 / 385
# Completed  123 / 385
# Completed  124 / 385
# Completed  125 / 385
# Completed  126 / 385
# Completed  127 / 385
# Completed  128 / 385
# Completed  129 / 385
# Completed  130 / 385
# Completed  131 / 385
# Completed  132 / 385
# Completed  133 / 385
# Completed  134 / 385
# Completed  135 / 385
# Completed  136 / 385
# Completed  137 / 385
# Completed  138 / 385
# Completed  139 / 385
# Completed  140 / 385
# Completed  141 / 385
# Completed  142 / 385
# Completed  143 / 385
# Completed  144 / 385
# Completed  145 / 385
# Completed  146 / 385
# Completed  147 / 385
# Completed  148 / 385
# Completed  149 / 385
# Completed  150 / 385
# Completed  151 / 385
# Completed  152 / 385
# Completed  153 / 385
# Completed  154 / 385
# Completed  155 / 385
# Completed  156 / 385
# Completed  157 / 385
# Completed  158 / 385
# Completed  159 / 385
# Completed  160 / 385
# Completed  161 / 385
# Completed  162 / 385
# Completed  163 / 385
# Completed  164 / 385
# Completed  165 / 385
# Completed  166 / 385
# Completed  167 / 385
# Completed  168 / 385
# Completed  169 / 385
# Completed  170 / 385
# Completed  171 / 385
# Completed  172 / 385
# Completed  173 / 385
# Completed  174 / 385
# Completed  175 / 385
# Completed  176 / 385
# Completed  177 / 385
# Completed  178 / 385
# Completed  179 / 385
# Completed  180 / 385
# Completed  181 / 385
# Completed  182 / 385
# Completed  183 / 385
# Completed  184 / 385
# Completed  185 / 385
# Completed  186 / 385
# Completed  187 / 385
# Completed  188 / 385
# Completed  189 / 385
# Completed  190 / 385
# Completed  191 / 385
# Completed  192 / 385
# Completed  193 / 385
# Completed  194 / 385
# Completed  195 / 385
# Completed  196 / 385
# Completed  197 / 385
# Completed  198 / 385
# Completed  199 / 385
# Completed  200 / 385
# Completed  201 / 385
# Completed  202 / 385
# Completed  203 / 385
# Completed  204 / 385
# Completed  205 / 385
# Completed  206 / 385
# Completed  207 / 385
# Completed  208 / 385
# Completed  209 / 385
# Completed  210 / 385
# Completed  211 / 385
# Completed  212 / 385
# Completed  213 / 385
# Completed  214 / 385
# Completed  215 / 385
# Completed  216 / 385
# Completed  217 / 385
# Completed  218 / 385
# Completed  219 / 385
# Completed  220 / 385
# Completed  221 / 385
# Completed  222 / 385
# Completed  223 / 385
# Completed  224 / 385
# Completed  225 / 385
# Completed  226 / 385
# Completed  227 / 385
# Completed  228 / 385
# Completed  229 / 385
# Completed  230 / 385
# Completed  231 / 385
# Completed  232 / 385
# Completed  233 / 385
# Completed  234 / 385
# Completed  235 / 385
# Completed  236 / 385
# Completed  237 / 385
# Completed  238 / 385
# Completed  239 / 385
# Completed  240 / 385
# Completed  241 / 385
# Completed  242 / 385
# Completed  243 / 385
# Completed  244 / 385
# Completed  245 / 385
# Completed  246 / 385
# Completed  247 / 385
# Completed  248 / 385
# Completed  249 / 385
# Completed  250 / 385
# Completed  251 / 385
# Completed  252 / 385
# Completed  253 / 385
# Completed  254 / 385
# Completed  255 / 385
# Completed  256 / 385
# Completed  257 / 385
# Completed  258 / 385
# Completed  259 / 385
# Completed  260 / 385
# Completed  261 / 385
# Completed  262 / 385
# Completed  263 / 385
# Completed  264 / 385
# Completed  265 / 385
# Completed  266 / 385
# Completed  267 / 385
# Completed  268 / 385
# Completed  269 / 385
# Completed  270 / 385
# Completed  271 / 385
# Completed  272 / 385
# Completed  273 / 385
# Completed  274 / 385
# Completed  275 / 385
# Completed  276 / 385
# Completed  277 / 385
# Completed  278 / 385
# Completed  279 / 385
# Completed  280 / 385
# Completed  281 / 385
# Completed  282 / 385
# Completed  283 / 385
# Completed  284 / 385
# Completed  285 / 385
# Completed  286 / 385
# Completed  287 / 385
# Completed  288 / 385
# Completed  289 / 385
# Completed  290 / 385
# Completed  291 / 385
# Completed  292 / 385
# Completed  293 / 385
# Completed  294 / 385
# Completed  295 / 385
# Completed  296 / 385
# Completed  297 / 385
# Completed  298 / 385
# Completed  299 / 385
# Completed  300 / 385
# Completed  301 / 385
# Completed  302 / 385
# Completed  303 / 385
# Completed  304 / 385
# Completed  305 / 385
# Completed  306 / 385
# Completed  307 / 385
# Completed  308 / 385
# Completed  309 / 385
# Completed  310 / 385
# Completed  311 / 385
# Completed  312 / 385
# Completed  313 / 385
# Completed  314 / 385
# Completed  315 / 385
# Completed  316 / 385
# Completed  317 / 385
# Completed  318 / 385
# Completed  319 / 385
# Completed  320 / 385
# Completed  321 / 385
# Completed  322 / 385
# Completed  323 / 385
# Completed  324 / 385
# Completed  325 / 385
# Completed  326 / 385
# Completed  327 / 385
# Completed  328 / 385
# Completed  329 / 385
# Completed  330 / 385
# Completed  331 / 385
# Completed  332 / 385
# Completed  333 / 385
# Completed  334 / 385
# Completed  335 / 385
# Completed  336 / 385
# Completed  337 / 385
# Completed  338 / 385
# Completed  339 / 385
# Completed  340 / 385
# Completed  341 / 385
# Completed  342 / 385
# Completed  343 / 385
# Completed  344 / 385
# Completed  345 / 385
# Completed  346 / 385
# Completed  347 / 385
# Completed  348 / 385
# Completed  349 / 385
# Completed  350 / 385
# Completed  351 / 385
# Completed  352 / 385
# Completed  353 / 385
# Completed  354 / 385
# Completed  355 / 385
# Completed  356 / 385
# Completed  357 / 385
# Completed  358 / 385
# Completed  359 / 385
# Completed  360 / 385
# Completed  361 / 385
# Completed  362 / 385
# Completed  363 / 385
# Completed  364 / 385
# Completed  365 / 385
# Completed  366 / 385
# Completed  367 / 385
# Completed  368 / 385
# Completed  369 / 385
# Completed  370 / 385
# Completed  371 / 385
# Completed  372 / 385
# Completed  373 / 385
# Completed  374 / 385
# Completed  375 / 385
# Completed  376 / 385
# Completed  377 / 385
# Completed  378 / 385
# Completed  379 / 385
# Completed  380 / 385
# Completed  381 / 385
# Completed  382 / 385
# Completed  383 / 385
# Completed  384 / 385
# Completed  385 / 385
# Data loaded in the file
# Working on Allview brand.
# Completed  1 / 143
# Completed  2 / 143
# Completed  3 / 143
# Completed  4 / 143
# Completed  5 / 143
# Completed  1 / 17
# Completed  2 / 17
# Completed  3 / 17
# Completed  4 / 17
# Completed  5 / 17
# Completed  6 / 17
# Completed  7 / 17
# Completed  8 / 17
# Completed  9 / 17
# Completed  10 / 17
# Completed  11 / 17
# Completed  12 / 17
# Completed  13 / 17
# Completed  14 / 17
# Completed  15 / 17
# Completed  16 / 17
# Completed  17 / 17
# Data loaded in the file
# Working on Amoi brand.
# Completed  1 / 47
# Completed  2 / 47
# Completed  3 / 47
# Completed  4 / 47
# Completed  5 / 47
# Completed  6 / 47
# Completed  7 / 47
# Completed  8 / 47
# Completed  9 / 47
# Completed  10 / 47
# Completed  11 / 47
# Completed  12 / 47
# Completed  13 / 47
# Completed  14 / 47
# Completed  15 / 47
# Completed  16 / 47
# Completed  17 / 47
# Completed  18 / 47
# Completed  19 / 47
# Completed  20 / 47
# Completed  21 / 47
# Completed  22 / 47
# Completed  23 / 47
# Completed  24 / 47
# Completed  25 / 47
# Completed  26 / 47
# Completed  27 / 47
# Completed  28 / 47
# Completed  29 / 47
# Completed  30 / 47
# Completed  31 / 47
# Completed  32 / 47
# Completed  33 / 47
# Completed  34 / 47
# Completed  35 / 47
# Completed  36 / 47
# Completed  37 / 47
# Completed  38 / 47
# Completed  39 / 47
# Completed  40 / 47
# Completed  41 / 47
# Completed  42 / 47
# Completed  43 / 47
# Completed  44 / 47
# Completed  45 / 47
# Completed  46 / 47
# Completed  47 / 47
# Data loaded in the file
# Working on Apple brand.
# Completed  1 / 67
# Completed  2 / 67
# Completed  3 / 67
# Completed  4 / 67
# Completed  5 / 67
# Completed  6 / 67
# Completed  7 / 67
# Completed  8 / 67
# Completed  9 / 67
# Completed  10 / 67
# Completed  11 / 67
# Completed  12 / 67
# Completed  13 / 67
# Completed  14 / 67
# Completed  15 / 67
# Completed  16 / 67
# Completed  17 / 67
# Completed  18 / 67
# Completed  19 / 67
# Completed  20 / 67
# Completed  21 / 67
# Completed  22 / 67
# Completed  23 / 67
# Completed  24 / 67
# Completed  25 / 67
# Completed  26 / 67
# Completed  27 / 67
# Completed  28 / 67
# Completed  29 / 67
# Completed  30 / 67
# Completed  31 / 67
# Completed  32 / 67
# Completed  33 / 67
# Completed  34 / 67
# Completed  35 / 67
# Completed  36 / 67
# Completed  37 / 67
# Completed  38 / 67
# Completed  39 / 67
# Completed  40 / 67
# Completed  41 / 67
# Completed  42 / 67
# Completed  43 / 67
# Completed  44 / 67
# Completed  45 / 67
# Completed  46 / 67
# Completed  47 / 67
# Completed  48 / 67
# Completed  49 / 67
# Completed  50 / 67
# Completed  51 / 67
# Completed  52 / 67
# Completed  53 / 67
# Completed  54 / 67
# Completed  55 / 67
# Completed  56 / 67
# Completed  57 / 67
# Completed  58 / 67
# Completed  59 / 67
# Completed  60 / 67
# Completed  61 / 67
# Completed  62 / 67
# Completed  63 / 67
# Completed  64 / 67
# Completed  65 / 67
# Completed  66 / 67
# Completed  67 / 67
# Data loaded in the file
# Working on Archos brand.
# Completed  1 / 43
# Completed  2 / 43
# Completed  3 / 43
# Completed  100 / 176
# Completed  101 / 176
# Completed  102 / 176
# Completed  103 / 176
# Completed  104 / 176
# Completed  105 / 176
# Completed  106 / 176
# Completed  107 / 176
# Completed  108 / 176
# Completed  109 / 176
# Completed  110 / 176
# Completed  111 / 176
# Completed  112 / 176
# Completed  113 / 176
# Completed  114 / 176
# Completed  115 / 176
# Completed  116 / 176
# Completed  117 / 176
# Completed  118 / 176
# Completed  119 / 176
# Completed  120 / 176
# Completed  121 / 176
# Completed  122 / 176
# Completed  123 / 176
# Completed  124 / 176
# Completed  125 / 176
# Completed  126 / 176
# Completed  127 / 176
# Completed  128 / 176
# Completed  129 / 176
# Completed  130 / 176
# Completed  131 / 176
# Completed  132 / 176
# Completed  133 / 176
# Completed  134 / 176
# Completed  135 / 176
# Completed  136 / 176
# Completed  137 / 176
# Completed  138 / 176
# Completed  139 / 176
# Completed  140 / 176
# Completed  141 / 176
# Completed  142 / 176
# Completed  143 / 176
# Completed  144 / 176
# Completed  145 / 176
# Completed  146 / 176
# Completed  147 / 176
# Completed  148 / 176
# Completed  149 / 176
# Completed  150 / 176
# Completed  151 / 176
# Completed  152 / 176
# Completed  153 / 176
# Completed  154 / 176
# Completed  155 / 176
# Completed  156 / 176
# Completed  157 / 176
# Completed  158 / 176
# Completed  159 / 176
# Completed  160 / 176
# Completed  161 / 176
# Completed  162 / 176
# Completed  163 / 176
# Completed  164 / 176
# Completed  165 / 176
# Completed  166 / 176
# Completed  167 / 176
# Completed  168 / 176
# Completed  169 / 176
# Completed  170 / 176
# Completed  171 / 176
# Completed  172 / 176
# Completed  173 / 176
# Completed  174 / 176
# Completed  175 / 176
# Completed  176 / 176
# Data loaded in the file
# Working on At&T brand.
# Completed  1 / 4
# Completed  2 / 4
# Completed  3 / 4
# Completed  4 / 4
# Data loaded in the file
# Working on Benefon brand.
# Completed  1 / 9
# Completed  2 / 9
# Completed  3 / 9
# Completed  4 / 9
# Completed  5 / 9
# Completed  6 / 9
# Completed  7 / 9
# Completed  8 / 9
# Completed  9 / 9
# Data loaded in the file
# Working on Benq brand.
# Completed  1 / 35
# Completed  2 / 35
# Completed  3 / 35
# Completed  4 / 35
# Completed  5 / 35
# Completed  6 / 35
# Completed  7 / 35
# Completed  8 / 35
# Completed  9 / 35
# Completed  10 / 35
# Completed  11 / 35
# Completed  12 / 35
# Completed  13 / 35
# Completed  14 / 35
# Completed  15 / 35
# Completed  16 / 35
# Completed  17 / 35
# Completed  18 / 35
# Completed  19 / 35
# Completed  20 / 35
# Completed  21 / 35
# Completed  22 / 35
# Completed  23 / 35
# Completed  24 / 35
# Completed  25 / 35
# Completed  26 / 35
# Completed  27 / 35
# Completed  28 / 35
# Completed  29 / 35
# Completed  30 / 35
# Completed  31 / 35
# Completed  32 / 35
# Completed  33 / 35
# Completed  34 / 35
# Completed  35 / 35
# Data loaded in the file
# Working on Benq_Siemens brand.
# Completed  1 / 27
# Completed  2 / 27
# Completed  3 / 27
# Completed  4 / 27
# Completed  5 / 27
# Completed  6 / 27
# Completed  7 / 27
# Completed  8 / 27
# Completed  9 / 27
# Completed  10 / 27
# Completed  11 / 27
# Completed  12 / 27
# Completed  13 / 27
# Completed  14 / 27
# Completed  15 / 27
# Completed  16 / 27
# Completed  17 / 27
# Completed  18 / 27
# Completed  19 / 27
# Completed  20 / 27
# Completed  21 / 27
# Completed  22 / 27
# Completed  23 / 27
# Completed  24 / 27
# Completed  25 / 27
# Completed  26 / 27
# Completed  27 / 27
# Data loaded in the file
# Working on Bird brand.
# Completed  1 / 61
# Completed  2 / 61
# Completed  3 / 61
# Completed  4 / 61
# Completed  5 / 61
# Completed  6 / 61
# Completed  7 / 61
# Completed  8 / 61
# Completed  9 / 61
# Completed  10 / 61
# Completed  11 / 61
# Completed  12 / 61
# Completed  13 / 61
# Completed  14 / 61
# Completed  15 / 61
# Completed  16 / 61
# Completed  17 / 61
# Completed  18 / 61
# Completed  19 / 61
# Completed  20 / 61
# Completed  21 / 61
# Completed  22 / 61
# Completed  23 / 61
# Completed  24 / 61
# Completed  25 / 61
# Completed  26 / 61
# Completed  27 / 61
# Completed  28 / 61
# Completed  29 / 61
# Completed  30 / 61
# Completed  31 / 61
# Completed  32 / 61
# Completed  33 / 61
# Completed  34 / 61
# Completed  35 / 61
# Completed  36 / 61
# Completed  37 / 61
# Completed  38 / 61
# Completed  39 / 61
# Completed  40 / 61
# Completed  41 / 61
# Completed  42 / 61
# Completed  43 / 61
# Completed  44 / 61
# Completed  45 / 61
# Completed  46 / 61
# Completed  47 / 61
# Completed  48 / 61
# Completed  49 / 61
# Completed  50 / 61
# Completed  51 / 61
# Completed  52 / 61
# Completed  53 / 61
# Completed  54 / 61
# Completed  55 / 61
# Completed  56 / 61
# Completed  57 / 61
# Completed  58 / 61
# Completed  59 / 61
# Completed  60 / 61
# Completed  61 / 61
# Data loaded in the file
# Working on Blackberry brand.
# Completed  1 / 92
# Completed  2 / 92
# Completed  3 / 92
# Completed  4 / 92
# Completed  5 / 92
# Completed  6 / 92
# Completed  7 / 92
# Completed  8 / 92
# Completed  9 / 92
# Completed  10 / 92
# Completed  11 / 92
# Completed  12 / 92
# Completed  13 / 92
# Completed  14 / 92
# Completed  15 / 92
# Completed  16 / 92
# Completed  17 / 92
# Completed  18 / 92
# Completed  19 / 92
# Completed  20 / 92
# Completed  21 / 92
# Completed  22 / 92
# Completed  23 / 92
# Completed  24 / 92
# Completed  25 / 92
# Completed  26 / 92
# Completed  27 / 92
# Completed  28 / 92
# Completed  29 / 92
# Completed  30 / 92
# Completed  31 / 92
# Completed  32 / 92
# Completed  33 / 92
# Completed  34 / 92
# Completed  35 / 92
# Completed  36 / 92
# Completed  37 / 92
# Completed  38 / 92
# Completed  39 / 92
# Completed  40 / 92
# Completed  41 / 92
# Completed  42 / 92
# Completed  43 / 92
# Completed  44 / 92
# Completed  45 / 92
# Completed  46 / 92
# Completed  47 / 92
# Completed  48 / 92
# Completed  49 / 92
# Completed  50 / 92
# Completed  51 / 92
# Completed  52 / 92
# Completed  53 / 92
# Completed  54 / 92
# Completed  55 / 92
# Completed  56 / 92
# Completed  57 / 92
# Completed  58 / 92
# Completed  59 / 92
# Completed  60 / 92
# Completed  61 / 92
# Completed  62 / 92
# Completed  63 / 92
# Completed  64 / 92
# Completed  65 / 92
# Completed  66 / 92
# Completed  67 / 92
# Completed  68 / 92
# Completed  69 / 92
# Completed  70 / 92
# Completed  71 / 92
# Completed  72 / 92
# Completed  73 / 92
# Completed  74 / 92
# Completed  75 / 92
# Completed  76 / 92
# Completed  77 / 92
# Completed  78 / 92
# Completed  79 / 92
# Completed  80 / 92
# Completed  81 / 92
# Completed  82 / 92
# Completed  83 / 92
# Completed  84 / 92
# Completed  85 / 92
# Completed  86 / 92
# Completed  87 / 92
# Completed  88 / 92
# Completed  89 / 92
# Completed  90 / 92
# Completed  91 / 92
# Completed  92 / 92
# Data loaded in the file
# Working on Blackview brand.
# Completed  1 / 6
# Completed  2 / 6
# Completed  3 / 6
# Completed  4 / 6
# Completed  5 / 6
# Completed  6 / 6
# Data loaded in the file
# Working on Blu brand.
# Completed  1 / 280
# Completed  2 / 280
# Completed  3 / 280
# Completed  4 / 280
# Completed  5 / 280
# Completed  6 / 280
# Completed  7 / 280
# Completed  8 / 280
# Completed  9 / 280
# Completed  10 / 280
# Completed  11 / 280
# Completed  12 / 280
# Completed  13 / 280
# Completed  14 / 280
# Completed  15 / 280
# Completed  16 / 280
# Completed  17 / 280
# Completed  18 / 280
# Completed  19 / 280
# Completed  20 / 280
# Completed  21 / 280
# Completed  22 / 280
# Completed  23 / 280
# Completed  24 / 280
# Completed  25 / 280
# Completed  26 / 280
# Completed  27 / 280
# Completed  28 / 280
# Completed  29 / 280
# Completed  30 / 280
# Completed  31 / 280
# Completed  32 / 280
# Completed  33 / 280
# Completed  34 / 280
# Completed  35 / 280
# Completed  36 / 280
# Completed  37 / 280
# Completed  38 / 280
# Completed  39 / 280
# Completed  40 / 280
# Completed  41 / 280
# Completed  42 / 280
# Completed  43 / 280
# Completed  44 / 280
# Completed  45 / 280
# Completed  46 / 280
# Completed  47 / 280
# Completed  48 / 280
# Completed  49 / 280
# Completed  50 / 280
# Completed  51 / 280
# Completed  52 / 280
# Completed  53 / 280
# Completed  54 / 280
# Completed  55 / 280
# Completed  56 / 280
# Completed  57 / 280
# Completed  58 / 280
# Completed  59 / 280
# Completed  60 / 280
# Completed  61 / 280
# Completed  62 / 280
# Completed  63 / 280
# Completed  64 / 280
# Completed  65 / 280
# Completed  66 / 280
# Completed  67 / 280
# Completed  68 / 280
# Completed  69 / 280
# Completed  70 / 280
# Completed  71 / 280
# Completed  72 / 280
# Completed  73 / 280
# Completed  74 / 280
# Completed  75 / 280
# Completed  76 / 280
# Completed  77 / 280
# Completed  78 / 280
# Completed  79 / 280
# Completed  80 / 280
# Completed  81 / 280
# Completed  82 / 280
# Completed  83 / 280
# Completed  84 / 280
# Completed  85 / 280
# Completed  86 / 280
# Completed  87 / 280
# Completed  88 / 280
# Completed  89 / 280
# Completed  90 / 280
# Completed  91 / 280
# Completed  92 / 280
# Completed  93 / 280
# Completed  94 / 280
# Completed  95 / 280
# Completed  96 / 280
# Completed  97 / 280
# Completed  98 / 280
# Completed  99 / 280
# Completed  100 / 280
# Completed  101 / 280
# Completed  102 / 280
# Completed  103 / 280
# Completed  104 / 280
# Completed  105 / 280
# Completed  106 / 280
# Completed  107 / 280
# Completed  108 / 280
# Completed  109 / 280
# Completed  110 / 280
# Completed  111 / 280
# Completed  112 / 280
# Completed  113 / 280
# Completed  114 / 280
# Completed  115 / 280
# Completed  116 / 280
# Completed  117 / 280
# Completed  118 / 280
# Completed  119 / 280
# Completed  120 / 280
# Completed  121 / 280
# Completed  122 / 280
# Completed  123 / 280
# Completed  124 / 280
# Completed  125 / 280
# Completed  126 / 280
# Completed  127 / 280
# Completed  128 / 280
# Completed  129 / 280
# Completed  130 / 280
# Completed  131 / 280
# Completed  132 / 280
# Completed  133 / 280
# Completed  134 / 280
# Completed  135 / 280
# Completed  136 / 280
# Completed  137 / 280
# Completed  138 / 280
# Completed  139 / 280
# Completed  140 / 280
# Completed  141 / 280
# Completed  142 / 280
# Completed  143 / 280
# Completed  144 / 280
# Completed  145 / 280
# Completed  146 / 280
# Completed  147 / 280
# Completed  148 / 280
# Completed  149 / 280
# Completed  150 / 280
# Completed  151 / 280
# Completed  152 / 280
# Completed  153 / 280
# Completed  154 / 280
# Completed  155 / 280
# Completed  156 / 280
# Completed  157 / 280
# Completed  158 / 280
# Completed  159 / 280
# Completed  160 / 280
# Completed  161 / 280
# Completed  162 / 280
# Completed  163 / 280
# Completed  164 / 280
# Completed  165 / 280
# Completed  166 / 280
# Completed  167 / 280
# Completed  168 / 280
# Completed  169 / 280
# Completed  170 / 280
# Completed  171 / 280
# Completed  172 / 280
# Completed  173 / 280
# Completed  174 / 280
# Completed  175 / 280
# Completed  176 / 280
# Completed  177 / 280
# Completed  178 / 280
# Completed  179 / 280
# Completed  180 / 280
# Completed  181 / 280
# Completed  182 / 280
# Completed  183 / 280
# Completed  184 / 280
# Completed  185 / 280
# Completed  186 / 280
# Completed  187 / 280
# Completed  188 / 280
# Completed  189 / 280
# Completed  190 / 280
# Completed  191 / 280
# Completed  192 / 280
# Completed  193 / 280
# Completed  194 / 280
# Completed  195 / 280
# Completed  196 / 280
# Completed  197 / 280
# Completed  198 / 280
# Completed  199 / 280
# Completed  200 / 280
# Completed  201 / 280
# Completed  202 / 280
# Completed  203 / 280
# Completed  204 / 280
# Completed  205 / 280
# Completed  206 / 280
# Completed  207 / 280
# Completed  208 / 280
# Completed  209 / 280
# Completed  210 / 280
# Completed  211 / 280
# Completed  212 / 280
# Completed  213 / 280
# Completed  214 / 280
# Completed  215 / 280
# Completed  216 / 280
# Completed  217 / 280
# Completed  218 / 280
# Completed  219 / 280
# Completed  220 / 280
# Completed  221 / 280
# Completed  222 / 280
# Completed  223 / 280
# Completed  224 / 280
# Completed  225 / 280
# Completed  226 / 280
# Completed  227 / 280
# Completed  228 / 280
# Completed  229 / 280
# Completed  230 / 280
# Completed  231 / 280
# Completed  232 / 280
# Completed  233 / 280
# Completed  234 / 280
# Completed  235 / 280
# Completed  236 / 280
# Completed  237 / 280
# Completed  238 / 280
# Completed  239 / 280
# Completed  240 / 280
# Completed  241 / 280
# Completed  242 / 280
# Completed  243 / 280
# Completed  244 / 280
# Completed  245 / 280
# Completed  246 / 280
# Completed  247 / 280
# Completed  248 / 280
# Completed  249 / 280
# Completed  250 / 280
# Completed  251 / 280
# Completed  252 / 280
# Completed  253 / 280
# Completed  254 / 280
# Completed  255 / 280
# Completed  256 / 280
# Completed  257 / 280
# Completed  258 / 280
# Completed  259 / 280
# Completed  260 / 280
# Completed  261 / 280
# Completed  262 / 280
# Completed  263 / 280
# Completed  264 / 280
# Completed  265 / 280
# Completed  266 / 280
# Completed  267 / 280
# Completed  268 / 280
# Completed  269 / 280
# Completed  270 / 280
# Completed  271 / 280
# Completed  272 / 280
# Completed  273 / 280
# Completed  274 / 280
# Completed  275 / 280
# Completed  276 / 280
# Completed  277 / 280
# Completed  278 / 280
# Completed  279 / 280
# Completed  280 / 280
# Data loaded in the file
# Working on Bosch brand.
# Completed  1 / 10
# Completed  2 / 10
# Completed  3 / 10
# Completed  4 / 10
# Completed  5 / 10
# Completed  6 / 10
# Completed  7 / 10
# Completed  8 / 10
# Completed  9 / 10
# Completed  10 / 10
# Data loaded in the file
# Working on Bq brand.
# Completed  1 / 20
# Completed  2 / 20
# Completed  3 / 20
# Completed  4 / 20
# Completed  5 / 20
# Completed  6 / 20
# Completed  7 / 20
# Completed  8 / 20
# Completed  9 / 20
# Completed  10 / 20
# Completed  11 / 20
# Completed  12 / 20
# Completed  13 / 20
# Completed  14 / 20
# Completed  15 / 20
# Completed  16 / 20
# Completed  17 / 20
# Completed  18 / 20
# Completed  19 / 20
# Completed  20 / 20
# Data loaded in the file
# Working on Casio brand.
# Completed  1 / 5
# Completed  2 / 5
# Completed  3 / 5
# Completed  4 / 5
# Completed  5 / 5
# Data loaded in the file
# Working on Cat brand.
# Completed  1 / 13
# Completed  2 / 13
# Completed  3 / 13
# Completed  4 / 13
# Completed  5 / 13
# Completed  6 / 13
# Completed  7 / 13
# Completed  8 / 13
# Completed  9 / 13
# Completed  10 / 13
# Completed  11 / 13
# Completed  12 / 13
# Completed  13 / 13
# Data loaded in the file
# Working on Celkon brand.
# Completed  1 / 229
# Completed  2 / 229
# Completed  3 / 229
# Completed  4 / 229
# Completed  5 / 229
# Completed  6 / 229
# Completed  7 / 229
# Completed  8 / 229
# Completed  9 / 229
# Completed  10 / 229
# Completed  11 / 229
# Completed  12 / 229
# Completed  13 / 229
# Completed  14 / 229
# Completed  15 / 229
# Completed  16 / 229
# Completed  17 / 229
# Completed  18 / 229
# Completed  19 / 229
# Completed  20 / 229
# Completed  21 / 229
# Completed  22 / 229
# Completed  23 / 229
# Completed  24 / 229
# Completed  25 / 229
# Completed  26 / 229
# Completed  27 / 229
# Completed  28 / 229
# Completed  29 / 229
# Completed  30 / 229
# Completed  31 / 229
# Completed  32 / 229
# Completed  33 / 229
# Completed  34 / 229
# Completed  35 / 229
# Completed  176 / 229
# Completed  177 / 229
# Completed  178 / 229
# Completed  179 / 229
# Completed  180 / 229
# Completed  181 / 229
# Completed  182 / 229
# Completed  183 / 229
# Completed  184 / 229
# Completed  185 / 229
# Completed  186 / 229
# Completed  187 / 229
# Completed  188 / 229
# Completed  189 / 229
# Completed  190 / 229
# Completed  191 / 229
# Completed  192 / 229
# Completed  193 / 229
# Completed  194 / 229
# Completed  195 / 229
# Completed  196 / 229
# Completed  197 / 229
# Completed  198 / 229
# Completed  199 / 229
# Completed  200 / 229
# Completed  201 / 229
# Completed  202 / 229
# Completed  203 / 229
# Completed  204 / 229
# Completed  205 / 229
# Completed  206 / 229
# Completed  207 / 229
# Completed  208 / 229
# Completed  209 / 229
# Completed  210 / 229
# Completed  211 / 229
# Completed  212 / 229
# Completed  213 / 229
# Completed  214 / 229
# Completed  215 / 229
# Completed  216 / 229
# Completed  217 / 229
# Completed  218 / 229
# Completed  219 / 229
# Completed  220 / 229
# Completed  221 / 229
# Completed  222 / 229
# Completed  223 / 229
# Completed  224 / 229
# Completed  225 / 229
# Completed  226 / 229
# Completed  227 / 229
# Completed  228 / 229
# Completed  229 / 229
# Data loaded in the file
# Working on Chea brand.
# Completed  1 / 12
# Completed  2 / 12
# Completed  3 / 12
# Completed  4 / 12
# Completed  5 / 12
# Completed  6 / 12
# Completed  7 / 12
# Completed  8 / 12
# Completed  9 / 12
# Completed  10 / 12
# Completed  11 / 12
# Completed  12 / 12
# Data loaded in the file
# Working on Coolpad brand.
# Completed  1 / 29
# Completed  2 / 29
# Completed  3 / 29
# Completed  4 / 29
# Completed  5 / 29
# Completed  6 / 29
# Completed  7 / 29
# Completed  8 / 29
# Completed  9 / 29
# Completed  10 / 29
# Completed  11 / 29
# Completed  12 / 29
# Completed  13 / 29
# Completed  14 / 29
# Completed  15 / 29
# Completed  16 / 29
# Completed  17 / 29
# Completed  18 / 29
# Completed  19 / 29
# Completed  20 / 29
# Completed  21 / 29
# Completed  22 / 29
# Completed  23 / 29
# Completed  24 / 29
# Completed  25 / 29
# Completed  26 / 29
# Completed  27 / 29
# Completed  28 / 29
# Completed  29 / 29
# Data loaded in the file
# Working on Dell brand.
# Completed  1 / 20
# Completed  2 / 20
# Completed  3 / 20
# Completed  4 / 20
# Completed  5 / 20
# Completed  6 / 20
# Completed  7 / 20
# Completed  8 / 20
# Completed  9 / 20
# Completed  10 / 20
# Completed  11 / 20
# Completed  12 / 20
# Completed  13 / 20
# Completed  14 / 20
# Completed  15 / 20
# Completed  16 / 20
# Completed  17 / 20
# Completed  18 / 20
# Completed  19 / 20
# Completed  20 / 20
# Data loaded in the file
# Working on Emporia brand.
# Completed  1 / 15
# Completed  2 / 15
# Completed  3 / 15
# Completed  4 / 15
# Completed  5 / 15
# Completed  6 / 15
# Completed  7 / 15
# Completed  8 / 15
# Completed  9 / 15
# Completed  10 / 15
# Completed  11 / 15
# Completed  12 / 15
# Completed  13 / 15
# Completed  14 / 15
# Completed  15 / 15
# Data loaded in the file
# Working on Energizer brand.
# Completed  1 / 45
# Completed  2 / 45
# Completed  3 / 45
# Completed  4 / 45
# Completed  5 / 45
# Completed  6 / 45
# Completed  7 / 45
# Completed  8 / 45
# Completed  9 / 45
# Completed  10 / 45
# Completed  11 / 45
# Completed  12 / 45
# Completed  13 / 45
# Completed  14 / 45
# Completed  15 / 45
# Completed  16 / 45
# Completed  17 / 45
# Completed  18 / 45
# Completed  19 / 45
# Completed  20 / 45
# Completed  21 / 45
# Completed  22 / 45
# Completed  23 / 45
# Completed  24 / 45
# Completed  25 / 45
# Completed  26 / 45
# Completed  27 / 45
# Completed  28 / 45
# Completed  29 / 45
# Completed  30 / 45
# Completed  31 / 45
# Completed  32 / 45
# Completed  33 / 45
# Completed  34 / 45
# Completed  35 / 45
# Completed  36 / 45
# Completed  37 / 45
# Completed  38 / 45
# Completed  39 / 45
# Completed  40 / 45
# Completed  41 / 45
# Completed  42 / 45
# Completed  43 / 45
# Completed  44 / 45
# Completed  45 / 45
# Data loaded in the file
# Working on Ericsson brand.
# Completed  1 / 40
# Completed  2 / 40
# Completed  3 / 40
# Completed  4 / 40
# Completed  5 / 40
# Completed  6 / 40
# Completed  7 / 40
# Completed  8 / 40
# Completed  9 / 40
# Completed  10 / 40
# Completed  11 / 40
# Completed  12 / 40
# Completed  13 / 40
# Completed  14 / 40
# Completed  15 / 40
# Completed  16 / 40
# Completed  17 / 40
# Completed  18 / 40
# Completed  19 / 40
# Completed  20 / 40
# Completed  21 / 40
# Completed  22 / 40
# Completed  23 / 40
# Completed  24 / 40
# Completed  25 / 40
# Completed  26 / 40
# Completed  27 / 40
# Completed  28 / 40
# Completed  29 / 40
# Completed  30 / 40
# Completed  31 / 40
# Completed  32 / 40
# Completed  33 / 40
# Completed  34 / 40
# Completed  35 / 40
# Completed  36 / 40
# Completed  37 / 40
# Completed  38 / 40
# Completed  39 / 40
# Completed  40 / 40
# Data loaded in the file
# Working on Eten brand.
# Completed  1 / 22
# Completed  2 / 22
# Completed  3 / 22
# Completed  4 / 22
# Completed  5 / 22
# Completed  6 / 22
# Completed  7 / 22
# Completed  8 / 22
# Completed  9 / 22
# Completed  10 / 22
# Completed  11 / 22
# Completed  12 / 22
# Completed  13 / 22
# Completed  14 / 22
# Completed  15 / 22
# Completed  16 / 22
# Completed  17 / 22
# Completed  18 / 22
# Completed  19 / 22
# Completed  20 / 22
# Completed  21 / 22
# Completed  22 / 22
# Data loaded in the file
# Working on Fujitsu_Siemens brand.
# Completed  1 / 2
# Completed  2 / 2
# Data loaded in the file
# Working on Garmin_Asus brand.
# Completed  1 / 5
# Completed  2 / 5
# Completed  3 / 5
# Completed  4 / 5
# Completed  5 / 5
# Data loaded in the file
# Working on Gigabyte brand.
# Completed  1 / 63
# Completed  2 / 63
# Completed  3 / 63
# Completed  4 / 63
# Completed  5 / 63
# Completed  6 / 63
# Completed  7 / 63
# Completed  8 / 63
# Completed  9 / 63
# Completed  10 / 63
# Completed  11 / 63
# Completed  12 / 63
# Completed  13 / 63
# Completed  14 / 63
# Completed  15 / 63
# Completed  16 / 63
# Completed  17 / 63
# Completed  18 / 63
# Completed  19 / 63
# Completed  20 / 63
# Completed  21 / 63
# Completed  22 / 63
# Completed  23 / 63
# Completed  24 / 63
# Completed  25 / 63
# Completed  26 / 63
# Completed  27 / 63
# Completed  28 / 63
# Completed  29 / 63
# Completed  30 / 63
# Completed  31 / 63
# Completed  32 / 63
# Completed  33 / 63
# Completed  34 / 63
# Completed  35 / 63
# Completed  36 / 63
# Completed  37 / 63
# Completed  38 / 63
# Completed  39 / 63
# Completed  40 / 63
# Completed  41 / 63
# Completed  42 / 63
# Completed  43 / 63
# Completed  44 / 63
# Completed  45 / 63
# Completed  46 / 63
# Completed  47 / 63
# Completed  48 / 63
# Completed  49 / 63
# Completed  50 / 63
# Completed  51 / 63
# Completed  52 / 63
# Completed  53 / 63
# Completed  54 / 63
# Completed  55 / 63
# Completed  56 / 63
# Completed  57 / 63
# Completed  58 / 63
# Completed  59 / 63
# Completed  60 / 63
# Completed  61 / 63
# Completed  62 / 63
# Completed  63 / 63
# Data loaded in the file
# Working on Gionee brand.
# Completed  1 / 79
# Completed  2 / 79
# Completed  3 / 79
# Completed  4 / 79
# Completed  5 / 79
# Completed  6 / 79
# Completed  7 / 79
# Completed  8 / 79
# Completed  9 / 79
# Completed  10 / 79
# Completed  11 / 79
# Completed  12 / 79
# Completed  13 / 79
# Completed  14 / 79
# Completed  15 / 79
# Completed  16 / 79
# Completed  17 / 79
# Completed  18 / 79
# Completed  19 / 79
# Completed  20 / 79
# Completed  21 / 79
# Completed  22 / 79
# Completed  23 / 79
# Completed  24 / 79
# Completed  25 / 79
# Completed  26 / 79
# Completed  27 / 79
# Completed  28 / 79
# Completed  29 / 79
# Completed  30 / 79
# Completed  31 / 79
# Completed  32 / 79
# Completed  33 / 79
# Completed  34 / 79
# Completed  35 / 79
# Completed  36 / 79
# Completed  37 / 79
# Completed  38 / 79
# Completed  39 / 79
# Completed  40 / 79
# Completed  41 / 79
# Completed  42 / 79
# Completed  43 / 79
# Completed  44 / 79
# Completed  45 / 79
# Completed  46 / 79
# Completed  47 / 79
# Completed  48 / 79
# Completed  49 / 79
# Completed  50 / 79
# Completed  51 / 79
# Completed  52 / 79
# Completed  53 / 79
# Completed  54 / 79
# Completed  55 / 79
# Completed  56 / 79
# Completed  57 / 79
# Completed  58 / 79
# Completed  59 / 79
# Completed  60 / 79
# Completed  61 / 79
# Completed  62 / 79
# Completed  63 / 79
# Completed  64 / 79
# Completed  65 / 79
# Completed  66 / 79
# Completed  67 / 79
# Completed  68 / 79
# Completed  69 / 79
# Completed  70 / 79
# Completed  71 / 79
# Completed  72 / 79
# Completed  73 / 79
# Completed  74 / 79
# Completed  75 / 79
# Completed  76 / 79
# Completed  77 / 79
# Completed  78 / 79
# Completed  79 / 79
# Data loaded in the file
# Working on Google brand.
# Completed  1 / 7
# Completed  2 / 7
# Completed  3 / 7
# Completed  4 / 7
# Completed  5 / 7
# Completed  6 / 7
# Completed  7 / 7
# Data loaded in the file
# Working on Haier brand.
# Completed  1 / 59
# Completed  2 / 59
# Completed  3 / 59
# Completed  4 / 59
# Completed  5 / 59
# Completed  6 / 59
# Completed  7 / 59
# Completed  8 / 59
# Completed  9 / 59
# Completed  10 / 59
# Completed  11 / 59
# Completed  12 / 59
# Completed  13 / 59
# Completed  14 / 59
# Completed  15 / 59
# Completed  16 / 59
# Completed  17 / 59
# Completed  18 / 59
# Completed  19 / 59
# Completed  20 / 59
# Completed  21 / 59
# Completed  22 / 59
# Completed  23 / 59
# Completed  24 / 59
# Completed  25 / 59
# Completed  26 / 59
# Completed  27 / 59
# Completed  28 / 59
# Completed  29 / 59
# Completed  30 / 59
# Completed  31 / 59
# Completed  32 / 59
# Completed  33 / 59
# Completed  34 / 59
# Completed  35 / 59
# Completed  36 / 59
# Completed  37 / 59
# Completed  38 / 59
# Completed  39 / 59
# Completed  40 / 59
# Completed  41 / 59
# Completed  42 / 59
# Completed  43 / 59
# Completed  44 / 59
# Completed  45 / 59
# Completed  46 / 59
# Completed  47 / 59
# Completed  48 / 59
# Completed  49 / 59
# Completed  50 / 59
# Completed  51 / 59
# Completed  52 / 59
# Completed  53 / 59
# Completed  54 / 59
# Completed  55 / 59
# Completed  56 / 59
# Completed  57 / 59
# Completed  58 / 59
# Completed  59 / 59
# Data loaded in the file
# Working on Honor brand.
# Completed  1 / 54
# Completed  2 / 54
# Completed  3 / 54
# Completed  4 / 54
# Completed  5 / 54
# Completed  6 / 54
# Completed  7 / 54
# Completed  8 / 54
# Completed  9 / 54
# Completed  10 / 54
# Completed  11 / 54
# Completed  12 / 54
# Completed  13 / 54
# Completed  14 / 54
# Completed  15 / 54
# Completed  16 / 54
# Completed  17 / 54
# Completed  18 / 54
# Completed  19 / 54
# Completed  20 / 54
# Completed  21 / 54
# Completed  22 / 54
# Completed  23 / 54
# Completed  24 / 54
# Completed  25 / 54
# Completed  26 / 54
# Completed  27 / 54
# Completed  28 / 54
# Completed  29 / 54
# Completed  30 / 54
# Completed  31 / 54
# Completed  32 / 54
# Completed  33 / 54
# Completed  34 / 54
# Completed  35 / 54
# Completed  36 / 54
# Completed  37 / 54
# Completed  38 / 54
# Completed  39 / 54
# Completed  40 / 54
# Completed  41 / 54
# Completed  42 / 54
# Completed  43 / 54
# Completed  44 / 54
# Completed  45 / 54
# Completed  46 / 54
# Completed  47 / 54
# Completed  48 / 54
# Completed  49 / 54
# Completed  50 / 54
# Completed  51 / 54
# Completed  52 / 54
# Completed  53 / 54
# Completed  54 / 54
# Data loaded in the file
# Working on Hp brand.
# Completed  1 / 41
# Completed  2 / 41
# Completed  3 / 41
# Completed  4 / 41
# Completed  5 / 41
# Completed  6 / 41
# Completed  7 / 41
# Completed  8 / 41
# Completed  9 / 41
# Completed  10 / 41
# Completed  11 / 41
# Completed  12 / 41
# Completed  13 / 41
# Completed  14 / 41
# Completed  15 / 41
# Completed  16 / 41
# Completed  17 / 41
# Completed  18 / 41
# Completed  19 / 41
# Completed  20 / 41
# Completed  21 / 41
# Completed  22 / 41
# Completed  23 / 41
# Completed  24 / 41
# Completed  444 / 623
# Completed  445 / 623
# Completed  446 / 623
# Completed  447 / 623
# Completed  448 / 623
# Completed  449 / 623
# Completed  450 / 623
# Completed  451 / 623
# Completed  452 / 623
# Completed  453 / 623
# Completed  454 / 623
# Completed  455 / 623
# Completed  456 / 623
# Completed  457 / 623
# Completed  458 / 623
# Completed  459 / 623
# Completed  460 / 623
# Completed  461 / 623
# Completed  462 / 623
# Completed  463 / 623
# Completed  464 / 623
# Completed  465 / 623
# Completed  466 / 623
# Completed  467 / 623
# Completed  468 / 623
# Completed  469 / 623
# Completed  470 / 623
# Completed  471 / 623
# Completed  472 / 623
# Completed  473 / 623
# Completed  474 / 623
# Completed  475 / 623
# Completed  476 / 623
# Completed  477 / 623
# Completed  478 / 623
# Completed  479 / 623
# Completed  480 / 623
# Completed  481 / 623
# Completed  482 / 623
# Completed  483 / 623
# Completed  484 / 623
# Completed  485 / 623
# Completed  486 / 623
# Completed  487 / 623
# Completed  488 / 623
# Completed  489 / 623
# Completed  490 / 623
# Completed  491 / 623
# Completed  492 / 623
# Completed  493 / 623
# Completed  494 / 623
# Completed  495 / 623
# Completed  496 / 623
# Completed  497 / 623
# Completed  498 / 623
# Completed  499 / 623
# Completed  500 / 623
# Completed  501 / 623
# Completed  502 / 623
# Completed  503 / 623
# Completed  504 / 623
# Completed  505 / 623
# Completed  506 / 623
# Completed  507 / 623
# Completed  508 / 623
# Completed  509 / 623
# Completed  510 / 623
# Completed  511 / 623
# Completed  512 / 623
# Completed  513 / 623
# Completed  514 / 623
# Completed  515 / 623
# Completed  516 / 623
# Completed  517 / 623
# Completed  518 / 623
# Completed  519 / 623
# Completed  520 / 623
# Completed  521 / 623
# Completed  522 / 623
# Completed  523 / 623
# Completed  524 / 623
# Completed  525 / 623
# Completed  526 / 623
# Completed  527 / 623
# Completed  528 / 623
# Completed  529 / 623
# Completed  530 / 623
# Completed  531 / 623
# Completed  532 / 623
# Completed  533 / 623
# Completed  534 / 623
# Completed  535 / 623
# Completed  536 / 623
# Completed  537 / 623
# Completed  538 / 623
# Completed  539 / 623
# Completed  540 / 623
# Completed  541 / 623
# Please check your network connection and re-run the script.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-6ce3a0568a24> in <module>
#     147         obj = Gsmarena()
#     148         try:
# --> 149             obj.save_specification_to_file()
#     150         except KeyboardInterrupt:
#     151             print("File has been stopped due to KeyBoard Interruption.")
#
# <ipython-input-1-6ce3a0568a24> in save_specification_to_file(self)
#     127                 print("Working on", brand[0].title(), "brand.")
#     128                 for value in link:
# --> 129                     datum = self.crawl_phones_models_specification(value, brand[0])
#     130                     datum = { k:v.replace('\n', ' ').replace('\r', ' ') for k,v in datum.items() }
#     131                     phones_data.append(datum)
#
# <ipython-input-1-6ce3a0568a24> in crawl_phones_models_specification(self, link, phone_brand)
#      73         phone_data = {}
#      74         soup = self.crawl_html_page(link)
# ---> 75         model_name = soup.find(class_='specs-phone-name-title').text
#      76         model_img_html = soup.find(class_='specs-photo-main')
#      77         model_img = model_img_html.find('img')['src']
#
# AttributeError: 'NoneType' object has no attribute 'find'
